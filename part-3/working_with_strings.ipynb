# %%
# piramid
step = int(input("height of piramid: "))
row = "*"
while step > 0:
    print(" "* step + row)
    row += "**"
    step -= 1
# Out:
#      *
#     ***
#    *****
#   *******
#  *********

# %%
# string multiplied
word = input("Enter your word:")
times= int(input("Enter number of times to print:"))
print(word*times)
# Out:
# jackjackjackjackjack

# %%
# The longer string
text1 = input("Please type in string 1:")
text2 = input("Please type in string 2:")
if len(text1) > len(text2):
    print(f"{text1} is longer")
elif len(text1) < len(text2):
    print(f"{text2} is longer")
else:
    print("The strings are equally long")
# Out:
# hello is longer

# %%
# print letters
word = input("Enter a string:")
index = 0
while index < len(word):
    print(word[index])
    index+=1
# Out:
# s
# u
# m
# i
# t

# %%
# Reverse letters
word = input("Enter a string:")
index = len(word)-1
while index >= 0:
    print(word[index])
    index -=1
# Out:
# t
# i
# m
# u
# s

# %%
# Second and second to last characters
word = input("Please type in a string:")
if word[1] == word[-2]:
    print(f"The second and the second to last characters are {word[1]}")
else:
    print("The second and the second to last characters are different")
# Out:
# The second and the second to last characters are a

# %%
# A rectangle of hashes
w = int(input("Width:"))
h = int(input("Height:"))
while h-1 >= 0:
    print(w*"#")
    h -= 1
# Out:
# ##########
# ##########
# ##########
# ##########

# %%
# text with underline
while True:
    word = input("Enter a string to write and and press blank to exit:")
    print(word)
    print("-"*len(word))

    if word == "":
        break
# Out:
# hello
# -----
# good evening!
# -------------

# %%
# Right-aligned
word = input("Enter a string:")
a = 20 - len(word)
if len(word) < 20:
    print("*"*a+word)
else:
    print(word)
# Out:
# *********good timing

# %%
# A framed word
word = input("Word:")
width = 30
print("*"*width)

space = width - 2 - len(word)
left = space//2
right = space - left
print("*"+" "*left+word+" "*right+"*")

print("*"*width)
# Out:
# ******************************
# *           sumit            *
# ******************************

# %%
# Substrings, part 1
word = input("Word:")
a = 0
while a<= len(word):
    print(word[0:a])
    a+=1
# Out:
# h
# he
# hel
# hell
# hello
# hellow
# hellowo
# hellowor
# helloworl
# helloworld

# %%
# Substrings, part 2
word = input("Word:")
a= len(word)
while a >= 0:
    print(word[a:])
    a-=1
# Out:
# t
# it
# mit
# umit
# sumit

# %%
# find vowels
vowels=['a' ,'e' , 'o' , 'i', 'u']
while True:
    word = input("Please type in a string:")
    for x in word:
        print(x)
        if x in vowels:
            print("found it!")
        else:
            print("not found")
    break
# Out:
# h
# not found
# e
# found it!
# l
# not found
# l
# not found
# o
# found it!

# %%
# Does it contain vowels
vowels = ['a','e','i','o','u']
word = input("Enter a word:")
while True:
    for v in vowels:
        if v in word:
            print(f"{v} found !")
        else:
            print(f"{v} not found !")
    break
print(f"input word:{word}")
# Out:
# a not found !
# e found !
# i not found !
# o found !
# u not found !
#  input word:hello

# %%
# Find the first substring
word = input("Enter a word:")
character = input("character:")

index = word.find(character)
print("word",word)
print("letter",character)
if index != -1 and index+3 <= len(word):
    print(word[index:index+3])
# Out:
# word banana
# letter b
# ban

# %%
# Find all the substrings
word = input("Word:")
character = input("character:")
print("word",word)
print("character", character)
while len(word) >= 3:
    if word[0] == character:
        print(word[:3])
    word = word[1:]
# Out:
# word incomprehensibilities
# character i
# inc
# ibi
# ili
# iti
# ies

# %%
# The second occurrence
string= input("String:")
substring = input("substring:")
first = string.find(substring)
print("string:",string)
print("substring:",substring)
if first == -1:
    print("The substring does not occur twice.")
else:
    second = string.find(substring , first + len(substring))
    if second == -1:
        print("The substring does not occur twice.")
    else:
        print(f"The substring occur twice at index {second}.")
# Out:
# string: abcabc
# substring ab
# The substring occur twice at index 3.
