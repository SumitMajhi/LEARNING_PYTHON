# %%
#Name twice
name = input("What is your name?")
print(name)
print(name)
# Out:
# Jack
# Jack

# %%
#Name and exclamation marks
name = input("What is your name?")
print(f"!{name}!{name}!")
# Out:
# !Jack!Jack!

# %%
# Name and address
a=input("Givenm name:")
b=input("Family name:")
c=input("Street address:")
d=input("City and postal code:")
print(a+' '+b)
print(c)
print(d)
# Out:
# Jack hammer
# street no-34
# Bermunda 1234

# %%
# Utterances
part = input("The 1st part: ")
parta = input("The 2st part: ")
partb = input("The 3st part: ")
print(part+"-"+ parta+"-" + partb+"!")
# Out:
# How-you-dowing!

# %%
# Story
name = input("Please type a name:")
year = input("Please type a year:")
print(f"""{name} is a valiant knight, born in the year {year}.
     One morning {name} woke up to an awful racket: a dragon was approaching the village.
     Only {name} could save the village's residents.""")
# Out:
# jack is a valiant knight, born in the year 1234. One morning jack woke up to an awful racket: a dragon was approaching the village. Only jack could save the village's residents.
