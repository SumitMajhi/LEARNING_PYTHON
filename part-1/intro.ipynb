# %%
# Please write a program which prints out an emoticon: :-)
print(":-)")
# Out:
# :-)

# %%
# Seven Brothers
names = ["Simeoni","Juhani","Eero","Lauri","Aapo","Tuomas","Timo"]
names.sort()
for name in names:
    print(name)
# Out:
# Aapo
# Eero
# Juhani
# Lauri
# Simeoni
# Timo
# Tuomas

# %%
#Please write a program which prints out the following lines exactly as they are written here, 
# punctuation and all:
Row, row, row your boat,
Gently down the stream.
Merrily, merrily, merrily, merrily,
Life is but a dream.

# %%
print("""Row, row, row your boat,
Gently down the stream.
Merrily, merrily, merrily, merrily,
Life is but a dream.""")
# Out:
# Row, row, row your boat,
# Gently down the stream.
# Merrily, merrily, merrily, merrily,
# Life is but a dream.

# %%
# Minutes in a year
year = 365
day = 24
hour = 60
minut = 60
minut_in_year = year*day*hour*minut
print(minut_in_year)
# Out:
# 31536000

# %%
#Print same code 
# "Come right back!", shouted the police officer.
print('"Come right back!", shouted the police officer.')
# Out:
# "Come right back!", shouted the police officer.

# %%
# Basic print function
