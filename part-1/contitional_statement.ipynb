# %%
# Orwell
a=int(input("Please type in a number:"))
if a == 1984:
    print("Orwell")
# Out:
# Orwell

# %%
# Absolute value
a = int(input("Please type in a number:"))
if a < 0:
    print("The absolute value of this number is", a* (-1))
else:
    print("The absolute value of this number is",a)
# Out:
# The absolute value of this number is 45

# %%
# Soup or no soup
name = input("Please tell me your name: ")
if name == "Jerry":
    print("Next please!")
else:
    portion = int(input("How many portions of soup?"))
    print("The total cost is",portion * 5.90)
    print("Next please!")
# Out:
# The total cost is 17.700000000000003
# Next please!

# %%
# Order of magnitude
a = int(input("Please type in a number: "))
if a < 1000:
    print("This number is smaller than 1000")
if a < 100:
    print("This number is smaller than 100")
if a < 10:
    print("This number is smaller than 10")

print("Thank you!")
# Out:
# This number is smaller than 1000
# Thank you!

# %%
# Calculator
a = int(input("Number 1:"))
b = int(input("Number 2:"))
opr = input("Operation:")

if opr == "add":
    print(f"{a} + {b} = {a+b}")

if opr == "subtract":
    print(f"{a} - {b} = {a-b}")

if opr == "multiply":
    print(f"{a} * {b} = {a*b}")
# Out:
# 2 + 7 = 9

# %%
# Temperatures
temp = int(input("Please type in a temperature (F):"))
print(f"{temp} degrees Fahrenheit equals {(temp-32)*5/9} degrees Celsius")
if temp < 32:
    print("Brr! It's cold in here!")
# Out:
# 23 degrees Fahrenheit equals -5.0 degrees Celsius
# Brr! It's cold in here!

# %%
# Daily wages
h = float(input("Hourly wage:"))
w = int(input("Hours worked:"))
d = input("Day of the week:")
if d == "Sunday":
    print(f"Daily wages: {(w*2)*h} euros")
else:
    print(f"Daily wages: {w*h} euros")
# Out:
# Daily wages: 184.0 euros

# %%
# Loyalty bonus
points = int(input("How many points are on your card? "))
if points < 100:
    points *= 1.1
    print("Your bonus is 10 %")

elif points >= 100:
    points *= 1.15
    print("Your bonus is 15 %")
else:
    print("Enter valid input!!!")

print("You now have", points, "points")
# Out:
# Your bonus is 15 %
# You now have 267.95 points

# %%
# What to wear tomorrow
a = "Wear jeans and a T-shirt"
b = "I recommend a jumper as well"
c = "Take a jacket with you"
d = """Make it a warm coat, actually
I think gloves are in order"""
e = "Don't forget your umbrella!"

temp = int(input("What is the weather forecast for tomorrow?\nTemperature: "))
rain = input("Will it rain (yes/no): ")

if temp <= 5:
    print(a)
    print(b)
    print(c)
    print(d)
    if rain == "yes":
        print(e)

elif temp <= 10:
    print(a)
    print(b)
    print(c)
    if rain == "yes":
        print(e)



elif temp <= 20:
    print(a)
    print(b)
    if rain == "yes":
        print(e)



else:
    print(a)
    if rain == "yes":
        print(e)
# Out:
# Wear jeans and a T-shirt
# I recommend a jumper as well
# Don't forget your umbrella!

# %%
# Solving a quadratic equation
from math import sqrt
a = int(input("Value of a:"))
b = int(input("Value of b:"))
c = int(input("Value of c:"))

dis = (b**2)-4*a*c

x1 = (-b + sqrt(dis))/ (2*a)
x2 = (-b - sqrt(dis))/ (2*a)
print(f"The roots are {x1} and {x2}")
# Out:
# The roots are 2.0 and -4.0
